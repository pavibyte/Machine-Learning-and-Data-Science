# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\VICTUS\OneDrive\Desktop\parent\Machine learning and data science\datasets\Housing.csv")

# %% [markdown]
# 1.What is the objective of this project?

# %% [markdown]
# The objective is to predict the price of the house based on various features. The data set already contains data where house prices are mentioned for a set of houses. Now, to predict the price of a new house, we train a model and find its price based on its understanding and analysis of previous data from the dataset.

# %% [markdown]
# 2.What is the target variable (what am I predicting)?

# %% [markdown]
# Iam predicting the price variable.

# %% [markdown]
# 3.What kind of ML problem is this? (classification/regression/…)

# %% [markdown]
# This is a regression problem where i predict the price of a house based on various features.

# %% [markdown]
# 4.Who would use this model in the real world?

# %% [markdown]
# This would be useful for people trying to find the price of a house when they want to buy one. Rather than just believing the price fixed by the real estate agent or the previous owner, we can determine the price ourselves that is right for its amenities. Real estate agents can also find and decide the right price for the property .

# %% [markdown]
# 5.What could go wrong if predictions are inaccurate?

# %% [markdown]
# If the predictions go wrong then the price for the house is not reliable. Prices would go up and down not based on the features rightly but incoorectly .

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df['price'].describe()
# Out:
# count    5.450000e+02
# mean     4.766729e+06
# std      1.870440e+06
# min      1.750000e+06
# 25%      3.430000e+06
# 50%      4.340000e+06
# 75%      5.740000e+06
# max      1.330000e+07
# Name: price, dtype: float64

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df['price'].describe()
# Out:
# count        545.00
# mean     4766729.25
# std      1870439.62
# min      1750000.00
# 25%      3430000.00
# 50%      4340000.00
# 75%      5740000.00
# max     13300000.00
# Name: price, dtype: float64

# %%
df.dtypes.value_counts()
# Out:
# object    7
# int64     6
# Name: count, dtype: int64

# %%
df.select_dtypes('object').columns
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.select_dtypes('int').columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking'], dtype='object')

# %%
missing = df.isnull().sum()
print(missing)
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
missing[missing > 0].sort_values(ascending = False)
# Out:
# Series([], dtype: int64)

# %%
df[['parking','area']].describe()
# Out:
#        parking     area
# count   545.00   545.00
# mean      0.69  5150.54
# std       0.86  2170.14
# min       0.00  1650.00
# 25%       0.00  3600.00
# 50%       0.00  4600.00
# 75%       1.00  6360.00
# max       3.00 16200.00

# %%
df[['area','price']].head()
# Out:
#    area     price
# 0  7420  13300000
# 1  8960  12250000
# 2  9960  12250000
# 3  7500  12215000
# 4  7420  11410000

# %% [markdown]
# When area increases, do I expect price to increase?

# %% [markdown]
# Generally yes.

# %% [markdown]
# Could there be cases where large area ≠ high price? Why?

# %% [markdown]
# yes , because there can be other factors affecting the price .

# %% [markdown]
# “Today I learned that ML starts with understanding data, not algorithms.”
